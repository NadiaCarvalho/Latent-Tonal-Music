# %% [markdown]
# <a href="https://colab.research.google.com/github/NadiaCarvalho/Latent-Tonal-Music/blob/main/Latent_Tonal_Music.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%time
# deps installation
try:
  import harmrep
except ImportError:
  # !git clone https://github.com/NadiaCarvalho/Latent-Tonal-Music.git
  # !pip install -e ./Latent-Tonal-Music -q
  print('Stopping RUNTIME! Please Restart Session and Run All.')
  import os
  os.kill(os.getpid(), 9)

# %%
from harmrep.encodings.enc_factory import EncoderFactory


encoding = 'pianoroll'

encoder = EncoderFactory().get_encoder(encoding, data_path='music21_bach',
                                               data_name='BachChorales', transposition='C Major')

# %%
from harmrep.model_train.train import Train

run_name='SEQ=10-AUG=FUD,OUD-BS=64-HD=32-DP=0.3-LR=0.00001-NL=1-M3'

train = Train(encoder, f'BachChorales_{encoding}_res4_transpC-Major_all_songs.pbz2')
train.start_training(run_name=run_name, dropout=0.3, batch_size=64, epochs=250, sequence_length=10, hidden_size=32, learning_rate=0.00001, num_layers=1, augmentations=['fifth-up-down', 'octave-up-down'])
